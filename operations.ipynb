# %%
import sentiment1
import json
from bson import json_util
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
import logging
import os
import warnings
import sys

# %%
logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)

sanitized = json.loads(json_util.dumps(sentiment1.temp_col.find()))
normalized = pd.json_normalize(sanitized)
df = pd.DataFrame(normalized)
df.sort_values('id', ascending = True, inplace = True)
df = df[pd.notnull(df['text'])]

df['Polarity_int'] = df['Polarity'].factorize()[0]

polarity_id_df = df[['Polarity', 'Polarity_int']].drop_duplicates().sort_values('Polarity_int')
polarity_to_id = dict(polarity_id_df.values)
id_to_polarity = dict(polarity_id_df[['Polarity_int', 'Polarity']].values)
print(df["Polarity_int"])
# Out:
# 0       0
# 1       1
# 2       2
# 3       2
# 4       1
#        ..
# 3941    1
# 3942    1
# 3943    2
# 3944    1
# 3945    1
# Name: Polarity_int, Length: 3946, dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'id', 'text', 'tweet', 'Sentiment', 'Score', 'Polarity',
#        'Tweet_punct', '_id.$oid', 'Polarity_int'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    index            id                                               text  \
# 0      0  1.502671e+18  RT @dabeard: Tip for today:\nIf anyone gets in...
# 1      1  1.502671e+18  #COVID19Germany #BA2variant  #BA2 48%\n"The nu...
# 2      2  1.502671e+18  RT @ignis_fatum: ‼️#Putin regime propaganda ag...
# 3      3  1.502671e+18  RT @EvanBlake17: @EricTopol @OurWorldInData Re...
# 4      4  1.502671e+18  RT @SaitamaUniverse: CryptoExpoDubai (Mar. 16-...
#
#                                                tweet Sentiment  Score  \
# 0  [rt, dabeard, tip, today, anyone, get, face, a...   Neutral  1.000
# 1  [covidgermany, bavariant, ba, number, people, ...     Happy  0.262
# 2  [rt, ignisfatum, putin, regime, propaganda, ag...       sad  0.251
# 3  [rt, evanblake, erictopol, ourworldindata, rec...       sad  0.218
# 4  [rt, saitamauniverse, cryptoexpodubai, mar, la...     Happy  0.231
#
#    Polarity                                        Tweet_punct  \
# 0   Neutral  rt dabeard tip for today\nif anyone gets in yo...
# 1  Positive  covidgermany bavariant  ba \nthe number of peo...
# 2  Negative  rt ignisfatum ‼️putin regime propaganda agency...
# 3  Negative  rt evanblake erictopol ourworldindata record c...
# 4  Positive  rt saitamauniverse cryptoexpodubai mar  is the...
#
#                    _id.$oid  Polarity_int
# 0  622d44f39fcffa7dd4311aa5             0
# 1  622d44f39fcffa7dd4311aa6             1
# 2  622d44f39fcffa7dd4311aa7             2
# 3  622d44f39fcffa7dd4311aa8             2
# 4  622d44f39fcffa7dd4311aa9             1

# %%
df=df[["text","Polarity","Polarity_int"]]
df.head(5)
# Out:
#                                                 text  Polarity  Polarity_int
# 0  RT @dabeard: Tip for today:\nIf anyone gets in...   Neutral             0
# 1  #COVID19Germany #BA2variant  #BA2 48%\n"The nu...  Positive             1
# 2  RT @ignis_fatum: ‼️#Putin regime propaganda ag...  Negative             2
# 3  RT @EvanBlake17: @EricTopol @OurWorldInData Re...  Negative             2
# 4  RT @SaitamaUniverse: CryptoExpoDubai (Mar. 16-...  Positive             1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=10, norm='l2', encoding='latin-1', ngram_range=(1,10), stop_words='english')

features = tfidf.fit_transform(df['text']).toarray()
labels = df['Polarity_int']
features.shape
# Out:
# (3946, 3042)

# %%
from sklearn.feature_selection import chi2
import numpy as np

N = 100000
for Polarity, polarity_int in sorted(polarity_to_id.items()):
  features_chi2 = chi2(features, labels == polarity_int)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(Polarity))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))
# Out:
# # 'Negative':
#   . Most correlated unigrams:
#        . therealplanc
#        . held
#        . brigade
#        . founder
#        . old
#        . zelensky
#        . billion
#        . region
#        . st
#        . look
#        . international
#        . bullish
#        . 17
#        . story
#        . eye
#        . watch
#        . mariupol
#        . covid19
#        . learn
#        . ba
#        . 11
#        . recently
#        . times
#        . 1000
#        . use
#        . leaders
#        . hear
#        . think
#        . buy
#        . develops
#        . moscow
#        . donetsk
#        . realise
#        . going
#        . 2021
#        . family
#        . pump
#        . civilians
#        . saying
#        . exchange
#        . feel
#        . major
#        . response
#        . doing
#        . test
#        . french
#        . want
#        . shot
#        . told
#        . following
#        . kherson
#        . does
#        . continue
#        . likely
#        . doesn
#        . used
#        . 24
#        . telling
#        . usa
#        . updates
#        . according
#        . fedorovmykhailo
#        . using
#        . global
#        . control
#        . person
#        . hours
#        . reportedly
#        . future
#        . youtube
#        . total
#        . believe
#        . largest
#        . india
#        . 12
#        . building
#        . gas
#        . mexico
#        . watcherguru
#        . 2020
#        . voting
#        . making
#        . breaking
#        . uk
#        . army
#        . america
#        . did
#        . zelenskyyua
#        . kremlin
#        . biden
#        . 10
#        . country
#        . point
#        . thing
#        . hope
#        . months
#        . pay
#        . energy
#        . gold
#        . talking
#        . twitter
#        . ll
#        . finance
#        . mar
#        . number
#        . foreign
#        . stock
#        . exchanges
#        . mining
#        . dennis_porter_
#        . case
#        . trying
#        . don
#        . big
#        . power
#        . showing
#        . pattern
#        . better
#        . bring
#        . 300
#        . captured
#        . supply
#        . france
#        . looking
#        . rt
#        . bank
#        . day
#        . nearly
#        . continues
#        . history
#        . ceo
#        . conducted
#        . mask
#        . launch
#        . equipment
#        . saturday
#        . food
#        . ukrainerussiawar
#        . china
#        . inside
#        . govt
#        . hit
#        . drericding
#        . meta
#        . bull
#        . nice
#        . lots
#        . 600
#        . women
#        . ago
#        . real
#        . 15
#        . comes
#        . time
#        . tank
#        . level
#        . central
#        . thank
#        . inflation
#        . aircraft
#        . 18
#        . yesterday
#        . prizes
#        . stsw
#        . stackswap_btc
#        . release
#        . sarang
#        . news
#        . says
#        . agree
#        . chart
#        . countries
#        . away
#        . lot
#        . people
#        . week
#        . amp
#        . 30
#        . business
#        . current
#        . taking
#        . volunteers
#        . high
#        . needs
#        . march
#        . airspace
#        . list
#        . come
#        . work
#        . innovation
#        . era
#        . proof
#        . tata_coin
#        . volodymyr
#        . tucker
#        . carlson
#        . minister
#        . national
#        . american
#        . mexicannewsiine
#        . today
#        . gets
#        . 28
#        . congress
#        . million
#        . shorts
#        . fixes
#        . far
#        . solution
#        . isn
#        . cases
#        . juliadavisnews
#        . clip
#        . silver
#        . coming
#        . able
#        . wants
#        . need
#        . based
#        . carrying
#        . le
#        . internet
#        . companies
#        . human
#        . steve
#        . potus
#        . aims
#        . liquidating
#        . instead
#        . children
#        . team
#        . coryklippsten
#        . 140
#        . xrpcommunity
#        . yeahh
#        . video
#        . wonder
#        . 70
#        . order
#        . hold
#        . goes
#        . tv
#        . key
#        . rovercrc
#        . protect
#        . defense
#        . dna
#        . right
#        . inteldoge
#        . considered
#        . sh
#        . amazing
#        . moment
#        . oil
#        . let
#        . rpg
#        . media
#        . doses
#        . coincidence
#        . yes
#        . positive
#        . corrupt
#        . soon
#        . cream
#        . provide
#        . tata
#        . life
#        . salvador
#        . company
#        . defichain
#        . elonmusk
#        . office
#        . sanctions
#        . open
#        . creamfinance
#        . new
#        . independent
#        . cannonfodder
#        . clue
#        . sheep
#        . easily
#        . blamegamebiden
#        . inf
#        . facedao
#        . billions
#        . love
#        . president
#        . powerful
#        . make
#        . just
#        . reuters
#        . shipments
#        . spread
#        . surrendered
#        . tests
#        . troops
#        . garethsoloway
#        . johnsweeneyroar
#        . feet
#        . 22
#        . years
#        . wallet
#        . kevinolearytv
#        . investor
#        . state
#        . vaccine
#        . trade
#        . onchainlabs
#        . btcanalysis
#        . kharkiv
#        . terra
#        . 5000
#        . jonathanweisman
#        . looks
#        . macro
#        . koraplay
#        . covid
#        . syria
#        . foodchain
#        . things
#        . saylor
#        . currency
#        . el
#        . bot
#        . plan
#        . th
#        . value
#        . apple
#        . chance
#        . tweet
#        . oblast
#        . signals
#        . post
#        . ukrainerussianwar
#        . 39
#        . retweet
#        . declare
#        . pool
#        . airdropdet
#        . long
#        . 19
#        . governments
#        . cutting
#        . join
#        . cryptocurrency
#        . kyiv
#        . service
#        . source
#        . 25
#        . manish_jha_brj
#        . game
#        . decentralized
#        . nftdrops
#        . item
#        . latest
#        . nation
#        . boosted
#        . 000th
#        . nftcollector
#        . secure
#        . gift
#        . bitcoins
#        . wish
#        . supplies
#        . host
#        . active
#        . goingparabolic
#        . cryptos
#        . estate
#        . great
#        . hospital
#        . ve
#        . canada
#        . flag
#        . checked
#        . confirmed
#        . 14
#        . blue_sauron
#        . shows
#        . like
#        . report
#        . web
#        . pandemic
#        . testing
#        . investors
#        . understand
#        . prices
#        . start
#        . support
#        . wozniak
#        . mined
#        . alexkokcharov
#        . early
#        . know
#        . accumulation
#        . moooon
#        . tokens
#        . daily
#        . rocket
#        . small
#        . picardonhealth
#        . fact
#        . jolitaihuttu
#        . city
#        . germany
#        . say
#        . propagandists
#        . ethereum
#        . blockchain
#        . https
#        . ukrainewar
#        . capture
#        . roll
#        . channel
#        . check
#        . maybe
#        . low
#        . usd
#        . status
#        . legal
#        . growing
#        . official
#        . portfolio
#        . ppl
#        . pundits
#        . kplay
#        . analysis
#        . face
#        . sell
#        . treasury
#        . study
#        . man
#        . dropped
#        . bought
#        . classic
#        . software
#        . bomb
#        . regulation
#        . invasion
#        . end
#        . ticket
#        . 03
#        . bnb
#        . interview
#        . joining
#        . ru
#        . position
#        . 16
#        . cardano
#        . share
#        . interesting
#        . luna
#        . xrpsec
#        . read
#        . wanted
#        . administered
#        . airdropinspect
#        . situation
#        . 82
#        . automated
#        . points
#        . banks
#        . announces
#        . wef
#        . account
#        . israel
#        . try
#        . holding
#        . nftart
#        . thecryptolark
#        . gm
#        . dubai
#        . talks
#        . 33
#        . head
#        . officialpoua
#        . coma
#        . che
#        . tender
#        . ripple
#        . guys
#        . 150
#        . public
#        . id
#        . perfect
#        . stackswap
#        . voted
#        . martiniguyyt
#        . giving
#        . community
#        . iran
#        . random
#        . information
#        . group
#        . nftartist
#        . trust
#        . melitopol
#        . coin
#        . closed
#        . 76
#        . ai
#        . pow
#        . berniespofforth
#        . nexta_tv
#        . month
#        . south
#        . marketplace
#        . woke
#        . government
#        . proposed
#        . strong
#        . financial
#        . 27
#        . payments
#        . peace
#        . getting
#        . 500
#        . days
#        . european
#        . airdropstario
#        . 21
#        . altcoin
#        . excellent
#        . innasovsun
#        . kyc
#        . audit
#        . tradeosiann
#        . free
#        . freeze
#        . jack
#        . vaccination
#        . dockaurg
#        . ones
#        . economic
#        . talk
#        . opensea
#        . metaverse
#        . 1000x
#        . presale
#        . zoom
#        . futures
#        . true
#        . telegram
#        . trudeau
#        . ukrainian
#        . documentingbtc
#        . law
#        . surge
#        . busd
#        . nftcommunity
#        . fly
#        . trading
#        . west
#        . states
#        . save
#        . friends
#        . worth
#        . thanks
#        . task
#        . health
#        . anti
#        . doge
#        . despite
#        . update
#        . token
#        . near
#        . help
#        . rate
#        . price
#        . rewards
#        . giveaway
#        . cryptowhale
#        . hundreds
#        . data
#        . link
#        . referring
#        . laurie_garrett
#        . home
#        . announced
#        . ground
#        . market
#        . military
#        . tsa
#        . rails
#        . rand
#        . butcher
#        . heartless
#        . paul
#        . soulless
#        . numbers28
#        . ayn
#        . western
#        . winners
#        . xrp
#        . denying
#        . publicly
#        . highlighted
#        . oversights
#        . existence
#        . negligence
#        . cryptojebb
#        . understood
#        . road
#        . reserves
#        . solovyov
#        . kremlinrussia_e
#        . deputy
#        . said
#        . reported
#        . reward
#        . scarce
#        . preparing
#        . live
#        . way
#        . basically
#        . limited
#        . canadian
#        . vote
#        . facebook
#        . kerala
#        . huge
#        . regime
#        . defi
#        . battle
#        . air
#        . digital
#        . london
#        . nft_sale_
#        . 2022
#        . money
#        . freedom
#        . started
#        . book
#        . forces
#        . disagree
#        . bitcoinmagazine
#        . forget
#        . ready
#        . referral
#        . record
#        . completely
#        . eth
#        . good
#        . 20
#        . paddi_hansen
#        . tpyxanews
#        . nato
#        . trump
#        . year
#        . mass
#        . matter
#        . ho
#        . thinks
#        . conflict
#        . nfts
#        . dollar
#        . currently
#        . stand
#        . hard
#        . 100
#        . tcells
#        . reports
#        . management
#        . passes
#        . possible
#        . pm
#        . indiatoday
#        . best
#        . pro
#        . 50
#        . eu
#        . russia
#        . world
#        . americans
#        . nftsplanett
#        . russianukrainianwar
#        . really
#        . weekly
#        . project
#        . follow
#        . binance
#        . 81
#        . called
#        . surrender
#        . meet
#        . btc
#        . serbia
#        . ajit
#        . censorship
#        . pai
#        . nationalized
#        . believing
#        . oryxspioenkop
#        . lowest
#        . wrote
#        . bitcoin
#        . left
#        . school
#        . gross
#        . russians
#        . federal
#        . block
#        . nft
#        . fsistanford
#        . fukuyamafrancis
#        . kashmir
#        . kanchangupta
#        . ethnic
#        . shameless
#        . glorifying
#        . denier
#        . cleansing
#        . chap
#        . disastrous
#        . worldwar3
#        . fight
#        . died
#        . mistake
#        . youranonnews
#        . russian
#        . rest
#        . given
#        . parliament
#        . nuclear
#        . higher
#        . 000
#        . zelenskyy
#        . crypto
#        . secretary
#        . lived
#        . btc_archive
#        . airdrop
#        . doubt
#        . provinces
#        . weeks
#        . risk
#        . danheld
#        . helicopter
#        . crisis
#        . mayor
#        . putin
#        . ka
#        . apartment
#        . assistant
#        . stop
#        . destroyed
#        . soldiers
#        . death
#        . 52
#        . weapons
#        . ukrainians
#        . abandoned
#        . ukraine
#        . detained
#        . banned
#        . fighting
#        . warns
#        . defeat
#        . charismanfts
#        . denmark
#        . moving
#        . rus
#        . levels
#        . dead
#        . lost
#        . got
#        . europe
#        . bad
#        . ban
#        . horizontal
#        . triangle
#        . ascending
#        . 42500
#        . resistance
#        . promote
#        . rejected
#        . killed
#        . cancelled
#        . propaganda
#        . attack
#        . deaths
#        . war
#   . Most correlated bigrams:
#        . crypto bitcoin
#        . nato russia
#        . equipment ukraine
#        . foreign minister
#        . rt independent
#        . rt drericding
#        . ukraine https
#        . decentralized finance
#        . watcherguru just
#        . deputy foreign
#        . rt dennis_porter_
#        . rt watcherguru
#        . covid19 cases
#        . bitcoin https
#        . russian troops
#        . bitcoin mining
#        . russian army
#        . 600 russian
#        . bitcoin cryptocurrency
#        . president volodymyr
#        . rovercrc bitcoin
#        . new cases
#        . reportedly ukrainian
#        . russian forces
#        . military equipment
#        . 10 000
#        . cryptocurrency bitcoin
#        . covid19 https
#        . week bitcoin
#        . russia https
#        . sarang india
#        . passes token
#        . prizes nfts
#        . stsw tokens
#        . tokens 000
#        . stackswap giveaway
#        . rt stackswap_btc
#        . token 10
#        . silver passes
#        . stackswap_btc stackswap
#        . 000 winners
#        . gold passes
#        . passes 000
#        . 10 gold
#        . 000 stsw
#        . 000 silver
#        . giveaway prizes
#        . bitcoin sarang
#        . country like
#        . rt tata_coin
#        . completely secure
#        . make decentralized
#        . coin new
#        . secure provide
#        . coin aims
#        . era finance
#        . finance completely
#        . aims make
#        . finance tata
#        . tata_coin tata
#        . tucker carlson
#        . russia invasion
#        . captured russian
#        . breaking mexico
#        . mexico declare
#        . rt mexicannewsiine
#        . mexicannewsiine breaking
#        . tender updates
#        . bitcoin fixes
#        . nfts 10
#        . day tucker
#        . rt juliadavisnews
#        . juliadavisnews day
#        . russians promote
#        . clip used
#        . carlson russia
#        . used russians
#        . tv clip
#        . looks like
#        . bitcoin amp
#        . rt rovercrc
#        . cannonfodder corrupt
#        . new era
#        . covid 19
#        . come story
#        . updates come
#        . story develops
#        . innasovsun russia
#        . freedom start
#        . just russians
#        . estate source
#        . source reuters
#        . billions bitcoin
#        . dubai real
#        . liquidating billions
#        . russians liquidating
#        . coryklippsten breaking
#        . rt coryklippsten
#        . xrp today
#        . cryptocurrency altcoin
#        . ripple cryptocurrency
#        . 70 000
#        . today 140
#        . 140 000
#        . altcoin xrpsec
#        . yesterday 70
#        . 000 yeahh
#        . 000 xrp
#        . xrpcommunity ripple
#        . yeahh xrpcommunity
#        . inside russia
#        . cream https
#        . ukraine considered
#        . minister says
#        . rt inteldoge
#        . russia deputy
#        . carrying military
#        . inteldoge russia
#        . breaking france
#        . btc_archive breaking
#        . troops surrendered
#        . zelensky says
#        . says 600
#        . creamfinance cream
#        . covid19 pandemic
#        . tata coin
#        . tender french
#        . french news
#        . france declare
#        . oblast russia
#        . el salvador
#        . bitcoin dubai
#        . rt garethsoloway
#        . follow live
#        . live ukraine
#        . russia amp
#        . luna creamfinance
#        . ppl clue
#        . clue easily
#        . ppl cannonfodder
#        . sheep ukraine
#        . easily sheep
#        . blamegamebiden usa
#        . usa ppl
#        . ukraine ppl
#        . airdropstario facedao
#        . referral million
#        . amp inf
#        . facedao airdrop
#        . task million
#        . face referral
#        . face airdrop
#        . task 5000
#        . 5000 kplay
#        . kplay referral
#        . 500 kplay
#        . koraplay airdrop
#        . kplay airdrop
#        . airdropstario koraplay
#        . referral 500
#        . signals bitcoin
#        . russia state
#        . bitcoin eth
#        . cutting supplies
#        . bot https
#        . johnsweeneyroar russian
#        . rt johnsweeneyroar
#        . army voting
#        . voting feet
#        . russia putin
#        . nftart nftcommunity
#        . nft nftart
#        . nftcommunity nftcollector
#        . btcanalysis onchainlabs
#        . amp information
#        . sanctions russia
#        . terra luna
#        . btc terra
#        . jonathanweisman 28
#        . rt jonathanweisman
#        . comes ba
#        . boosted 28
#        . 28 comes
#        . 28 boosted
#        . foodchain global
#        . worth food
#        . food rate
#        . 1000 random
#        . food total
#        . airdrop foodchain
#        . global food
#        . winners 1000
#        . don know
#        . web https
#        . rt goingparabolic
#        . pool start
#        . referral pool
#        . airdrop bot
#        . amp crypto
#        . real estate
#        . nfts nft
#        . declare bitcoin
#        . rt airdropdet
#        . start airdrop
#        . airdropdet new
#        . crypto https
#        . powerful country
#        . rt manish_jha_brj
#        . like america
#        . america china
#        . russia powerful
#        . opensea nft
#        . check item
#        . nftdrops https
#        . nftartist nftdrops
#        . item opensea
#        . nftcommunity nftartist
#        . marketplace https
#        . 22 days
#        . 19 000
#        . days 19
#        . 000 000th
#        . 000th bitcoin
#        . think bitcoin
#        . amp 100
#        . martiniguyyt week
#        . bitcoin great
#        . gift 150
#        . 150 bitcoins
#        . wish gift
#        . ukrainian air
#        . eu pow
#        . rt blue_sauron
#        . marketplace web
#        . nft nfts
#        . steve wozniak
#        . ticket financial
#        . bitcoin mined
#        . rt alexkokcharov
#        . nexta_tv new
#        . reward 000
#        . russia ukraine
#        . million face
#        . state tv
#        . moooon altcoin
#        . altcoin bitcoin
#        . xrp ripple
#        . ready moooon
#        . xrp getting
#        . bitcoin binance
#        . ripple xrpsec
#        . binance xrp
#        . financial freedom
#        . apple founder
#        . 20 000
#        . covid19 update
#        . rt jolitaihuttu
#        . russian tank
#        . 12 03
#        . 03 2022
#        . airdrop link
#        . link amp
#        . announced yesterday
#        . capture dna
#        . id wef
#        . roll digital
#        . wef capture
#        . plan roll
#        . coincidence announced
#        . berniespofforth coincidence
#        . yesterday plan
#        . nfts nftcommunity
#        . bitcoin ethereum
#        . days bitcoin
#        . software ticket
#        . russia doing
#        . russia announced
#        . new sanctions
#        . rt picardonhealth
#        . trading software
#        . vaccine doses
#        . 000 worth
#        . random amp
#        . telegram channel
#        . announced today
#        . rt saylor
#        . cryptocurrency trading
#        . xrpsec https
#        . opensea https
#        . bitcoin going
#        . going 100
#        . rt airdropinspect
#        . total reward
#        . airdropinspect new
#        . rate winners
#        . automated cryptocurrency
#        . freedom automated
#        . rt thecryptolark
#        . rt nexta_tv
#        . saylor bitcoin
#        . bitcoin legal
#        . march 2022
#        . bitcoin freedom
#        . airdrop task
#        . 50 000
#        . don position
#        . position bitcoin
#        . woke year
#        . eth just
#        . che https
#        . just woke
#        . year coma
#        . macro che
#        . coma checked
#        . checked macro
#        . legal tender
#        . digital id
#        . rt martiniguyyt
#        . pow ban
#        . cryptojebb bitcoin
#        . getting ready
#        . ukrainian forces
#        . rt airdropstario
#        . nft marketplace
#        . bitcoin currently
#        . rt berniespofforth
#        . proof work
#        . btc_archive bitcoin
#        . rt innasovsun
#        . audit busd
#        . rewards nft
#        . kyc audit
#        . busd rewards
#        . token kyc
#        . 1000x token
#        . rocket ready
#        . binance futures
#        . fly follow
#        . shorts binance
#        . follow tradeosiann
#        . tradeosiann https
#        . futures rocket
#        . 50 shorts
#        . ready fly
#        . alexkokcharov russia
#        . rt dockaurg
#        . rt cryptojebb
#        . bitcoin exchange
#        . sanctions like
#        . live soon
#        . soon 1000x
#        . presale live
#        . bitcoinmagazine banks
#        . rt documentingbtc
#        . bitcoin btc
#        . scarce understood
#        . bitcoin scarce
#        . new airdrop
#        . times ll
#        . start referring
#        . say pundits
#        . said times
#        . referring covid19
#        . pundits start
#        . ve said
#        . laurie_garrett ve
#        . rt laurie_garrett
#        . rt numbers28
#        . rails tsa
#        . rand ayn
#        . heartless soulless
#        . russian butcher
#        . paul rails
#        . congress rand
#        . butcher propagandists
#        . propagandists congress
#        . soulless russian
#        . ayn paul
#        . numbers28 heartless
#        . 100 000
#        . denying existence
#        . gross oversights
#        . trudeau govt
#        . highlighted trudeau
#        . amp negligence
#        . oversights amp
#        . govt gross
#        . tcells publicly
#        . negligence denying
#        . existence tcells
#        . talk sanctions
#        . says talk
#        . solovyov says
#        . propagandists solovyov
#        . kremlin propagandists
#        . russia kremlin
#        . years ago
#        . breaking bitcoin
#        . promote nft_sale_
#        . disagree bitcoin
#        . regulation voted
#        . just bitcoin
#        . reserves dropped
#        . news bitcoin
#        . work mining
#        . bitcoin proof
#        . eu crypto
#        . cryptowhale breaking
#        . ban way
#        . way eu
#        . crypto regulation
#        . rt tpyxanews
#        . bitcoin crypto
#        . ll say
#        . rt cryptowhale
#        . dropped lowest
#        . level years
#        . lowest level
#        . russia china
#        . mining ban
#        . exchange reserves
#        . ukraine russia
#        . rt indiatoday
#        . banks freeze
#        . freeze money
#        . money disagree
#        . promote nftsplanett
#        . rt bitcoinmagazine
#        . internet censorship
#        . china post
#        . ajit pai
#        . trump ajit
#        . rt youranonnews
#        . mistake believing
#        . limited russia
#        . pai ho
#        . post trump
#        . censorship limited
#        . youranonnews mistake
#        . nationalized internet
#        . believing nationalized
#        . rt oryxspioenkop
#        . zoom bitcoin
#        . doubt zoom
#        . danheld doubt
#        . russia russianukrainianwar
#        . ground fukuyamafrancis
#        . needs start
#        . defeat rus
#        . world needs
#        . fsistanford given
#        . fukuyamafrancis thinks
#        . preparing defeat
#        . given situation
#        . thinks world
#        . rt fsistanford
#        . start preparing
#        . situation ground
#        . kanchangupta meet
#        . ethnic cleansing
#        . shameless kashmir
#        . rt kanchangupta
#        . glorifying kerala
#        . kashmir ethnic
#        . denier chap
#        . cleansing denier
#        . chap wrote
#        . book glorifying
#        . kerala disastrous
#        . disastrous management
#        . meet shameless
#        . wrote book
#        . rt btc_archive
#        . bad news
#        . secretary health
#        . rt danheld
#        . 81 people
#        . ka 52
#        . assistant secretary
#        . people died
#        . promote charismanfts
#        . russia lost
#        . bitcoinmagazine bitcoin
#        . covid19 deaths
#        . russia war
#        . ukraine war
#        . war ukraine
#        . bitcoin cancelled
#        . horizontal resistance
#        . bitcoin moving
#        . ascending triangle
#        . got rejected
#        . 42500 currently
#        . triangle got
#        . currently https
#        . rejected horizontal
#        . moving ascending
#        . resistance 42500
# # 'Neutral':
#   . Most correlated unigrams:
#        . based
#        . chart
#        . zoom
#        . according
#        . volunteers
#        . 21
#        . germany
#        . ukrainerussiawar
#        . things
#        . analysis
#        . dropped
#        . latest
#        . ukrainerussianwar
#        . oil
#        . told
#        . family
#        . donetsk
#        . vote
#        . trying
#        . exchanges
#        . business
#        . ukrainewar
#        . 70
#        . west
#        . major
#        . 20
#        . syria
#        . ground
#        . regulation
#        . pump
#        . mass
#        . reports
#        . 15
#        . 76
#        . cryptojebb
#        . history
#        . 24
#        . old
#        . isn
#        . defense
#        . launch
#        . possible
#        . european
#        . public
#        . lot
#        . tweet
#        . news
#        . big
#        . host
#        . london
#        . live
#        . shows
#        . prices
#        . xrpsec
#        . held
#        . reserves
#        . day
#        . invasion
#        . parliament
#        . telegram
#        . garethsoloway
#        . instead
#        . innasovsun
#        . mask
#        . bnb
#        . look
#        . supply
#        . corrupt
#        . watch
#        . kerala
#        . largest
#        . month
#        . say
#        . 2020
#        . russian
#        . bull
#        . talks
#        . school
#        . test
#        . proposed
#        . cases
#        . supplies
#        . st
#        . uk
#        . kherson
#        . 50
#        . canada
#        . taking
#        . bitcoinmagazine
#        . biden
#        . come
#        . gold
#        . billion
#        . food
#        . dollar
#        . kharkiv
#        . russianukrainianwar
#        . fixes
#        . nearly
#        . 17
#        . right
#        . ru
#        . rpg
#        . ba
#        . bomb
#        . surge
#        . ripple
#        . drericding
#        . low
#        . rest
#        . governments
#        . anti
#        . getting
#        . release
#        . government
#        . airdrop
#        . hospital
#        . decentralized
#        . picardonhealth
#        . referral
#        . doesn
#        . nation
#        . russia
#        . leaders
#        . facebook
#        . deputy
#        . national
#        . states
#        . make
#        . 82
#        . tucker
#        . carlson
#        . ago
#        . foreign
#        . china
#        . international
#        . oryxspioenkop
#        . need
#        . eu
#        . think
#        . tpyxanews
#        . america
#        . telling
#        . points
#        . nft
#        . altcoin
#        . cardano
#        . thing
#        . covid
#        . 81
#        . regime
#        . says
#        . pandemic
#        . current
#        . believe
#        . used
#        . paddi_hansen
#        . 33
#        . 16
#        . holding
#        . shipments
#        . zelenskyy
#        . continues
#        . ho
#        . usa
#        . man
#        . finance
#        . times
#        . shot
#        . spread
#        . founder
#        . 25
#        . guys
#        . key
#        . captured
#        . preparing
#        . reported
#        . ll
#        . human
#        . lots
#        . 300
#        . use
#        . mayor
#        . understand
#        . 11
#        . trade
#        . canadian
#        . coin
#        . breaking
#        . le
#        . sanctions
#        . 100
#        . price
#        . situation
#        . 2021
#        . tv
#        . trading
#        . cryptocurrency
#        . stackswap_btc
#        . prizes
#        . stsw
#        . near
#        . did
#        . basically
#        . 600
#        . accumulation
#        . bullish
#        . women
#        . melitopol
#        . oblast
#        . global
#        . iran
#        . covid19
#        . defichain
#        . western
#        . zelensky
#        . hold
#        . gets
#        . let
#        . kyiv
#        . martiniguyyt
#        . binance
#        . retweet
#        . talking
#        . hundreds
#        . 28
#        . volodymyr
#        . left
#        . interview
#        . management
#        . story
#        . 30
#        . tata_coin
#        . investor
#        . city
#        . country
#        . start
#        . youtube
#        . end
#        . ukraine
#        . referring
#        . laurie_garrett
#        . making
#        . people
#        . years
#        . mexicannewsiine
#        . channel
#        . carrying
#        . numbers28
#        . heartless
#        . soulless
#        . rails
#        . paul
#        . rand
#        . butcher
#        . tsa
#        . ayn
#        . denying
#        . existence
#        . negligence
#        . oversights
#        . publicly
#        . highlighted
#        . 12
#        . 27
#        . wanted
#        . juliadavisnews
#        . clip
#        . silver
#        . independent
#        . troops
#        . follow
#        . hit
#        . testing
#        . power
#        . trump
#        . steve
#        . banks
#        . american
#        . th
#        . bot
#        . home
#        . just
#        . french
#        . able
#        . account
#        . countries
#        . tokens
#        . aims
#        . report
#        . stand
#        . coryklippsten
#        . watcherguru
#        . week
#        . following
#        . future
#        . federal
#        . response
#        . total
#        . pool
#        . airdropdet
#        . ukrainian
#        . pundits
#        . months
#        . india
#        . small
#        . wallet
#        . nato
#        . ve
#        . apple
#        . looking
#        . pro
#        . thecryptolark
#        . inflation
#        . develops
#        . companies
#        . doing
#        . equipment
#        . provide
#        . therealplanc
#        . state
#        . tata
#        . france
#        . investors
#        . tcells
#        . buy
#        . indiatoday
#        . hours
#        . game
#        . list
#        . 03
#        . despite
#        . conducted
#        . 150
#        . easily
#        . sheep
#        . cannonfodder
#        . clue
#        . blamegamebiden
#        . service
#        . learn
#        . confirmed
#        . inside
#        . world
#        . giveaway
#        . saturday
#        . wozniak
#        . twitter
#        . nexta_tv
#        . mar
#        . luna
#        . face
#        . censorship
#        . ajit
#        . pai
#        . nationalized
#        . believing
#        . early
#        . dockaurg
#        . law
#        . financial
#        . said
#        . lowest
#        . reportedly
#        . yes
#        . fedorovmykhailo
#        . disagree
#        . gross
#        . soldiers
#        . jonathanweisman
#        . congress
#        . work
#        . continue
#        . fukuyamafrancis
#        . fsistanford
#        . tests
#        . pattern
#        . foodchain
#        . denier
#        . chap
#        . cleansing
#        . ethnic
#        . disastrous
#        . kashmir
#        . kanchangupta
#        . glorifying
#        . shameless
#        . source
#        . children
#        . order
#        . really
#        . goingparabolic
#        . mistake
#        . terra
#        . xrp
#        . showing
#        . trudeau
#        . airspace
#        . air
#        . head
#        . aircraft
#        . youranonnews
#        . person
#        . mexico
#        . does
#        . declare
#        . gas
#        . level
#        . era
#        . cutting
#        . govt
#        . real
#        . don
#        . task
#        . sarang
#        . manish_jha_brj
#        . boosted
#        . new
#        . wrote
#        . record
#        . time
#        . israel
#        . currency
#        . gift
#        . bitcoins
#        . wish
#        . billions
#        . point
#        . lived
#        . life
#        . book
#        . voted
#        . hear
#        . army
#        . post
#        . 1000
#        . 14
#        . talk
#        . way
#        . dubai
#        . web
#        . president
#        . doubt
#        . far
#        . provinces
#        . health
#        . forces
#        . danheld
#        . meet
#        . helicopter
#        . serbia
#        . blue_sauron
#        . company
#        . moooon
#        . central
#        . freeze
#        . jolitaihuttu
#        . case
#        . zelenskyyua
#        . random
#        . 500
#        . ka
#        . apartment
#        . meta
#        . read
#        . given
#        . thinks
#        . passes
#        . called
#        . million
#        . updates
#        . started
#        . growing
#        . fly
#        . cream
#        . pow
#        . status
#        . assistant
#        . ppl
#        . dennis_porter_
#        . active
#        . media
#        . treasury
#        . money
#        . proof
#        . 52
#        . positive
#        . classic
#        . salvador
#        . soon
#        . payments
#        . software
#        . ones
#        . kremlin
#        . pay
#        . military
#        . nuclear
#        . token
#        . ceo
#        . secretary
#        . ticket
#        . marketplace
#        . coming
#        . energy
#        . abandoned
#        . eye
#        . detained
#        . banned
#        . moscow
#        . internet
#        . futures
#        . 18
#        . team
#        . road
#        . creamfinance
#        . share
#        . interesting
#        . vaccine
#        . innovation
#        . ethereum
#        . forget
#        . know
#        . block
#        . comes
#        . wonder
#        . joining
#        . dead
#        . airdropinspect
#        . russians
#        . video
#        . automated
#        . higher
#        . warns
#        . information
#        . realise
#        . saying
#        . protect
#        . pm
#        . defeat
#        . surrender
#        . presale
#        . 1000x
#        . bring
#        . sell
#        . amp
#        . crypto
#        . doses
#        . chance
#        . denmark
#        . days
#        . exchange
#        . maybe
#        . putin
#        . sh
#        . worldwar3
#        . battle
#        . americans
#        . secure
#        . hard
#        . tender
#        . agree
#        . 2022
#        . airdropstario
#        . limited
#        . perfect
#        . daily
#        . destroyed
#        . weapons
#        . amazing
#        . giving
#        . moment
#        . kremlinrussia_e
#        . link
#        . death
#        . going
#        . trust
#        . conflict
#        . today
#        . value
#        . 10
#        . goes
#        . moving
#        . weekly
#        . building
#        . civilians
#        . better
#        . powerful
#        . matter
#        . fight
#        . legal
#        . koraplay
#        . doge
#        . voting
#        . 19
#        . region
#        . crisis
#        . 5000
#        . brigade
#        . weeks
#        . rus
#        . onchainlabs
#        . btcanalysis
#        . data
#        . completely
#        . try
#        . excellent
#        . audit
#        . kyc
#        . signals
#        . number
#        . tradeosiann
#        . cryptowhale
#        . hope
#        . usd
#        . resistance
#        . liquidating
#        . group
#        . levels
#        . got
#        . feel
#        . xrpcommunity
#        . yeahh
#        . 140
#        . economic
#        . el
#        . kevinolearytv
#        . minister
#        . using
#        . true
#        . rocket
#        . busd
#        . stock
#        . solution
#        . bank
#        . save
#        . friends
#        . thanks
#        . mining
#        . blockchain
#        . looks
#        . considered
#        . inteldoge
#        . free
#        . risk
#        . away
#        . administered
#        . shorts
#        . thank
#        . likely
#        . rate
#        . community
#        . horizontal
#        . 42500
#        . triangle
#        . ascending
#        . rewards
#        . ukrainians
#        . update
#        . metaverse
#        . winners
#        . control
#        . bought
#        . rejected
#        . recently
#        . study
#        . killed
#        . solovyov
#        . bad
#        . cancelled
#        . love
#        . 39
#        . facedao
#        . inf
#        . peace
#        . propagandists
#        . died
#        . wants
#        . flag
#        . huge
#        . alexkokcharov
#        . reuters
#        . strong
#        . fighting
#        . office
#        . surrendered
#        . long
#        . johnsweeneyroar
#        . feet
#        . nft_sale_
#        . freedom
#        . tank
#        . propaganda
#        . fact
#        . portfolio
#        . reward
#        . nice
#        . lost
#        . project
#        . south
#        . currently
#        . market
#        . btc
#        . gm
#        . announces
#        . saylor
#        . kplay
#        . 22
#        . check
#        . join
#        . dna
#        . rt
#        . item
#        . nftdrops
#        . coincidence
#        . 000th
#        . rovercrc
#        . ban
#        . high
#        . nftcollector
#        . opensea
#        . cryptos
#        . estate
#        . potus
#        . best
#        . march
#        . deaths
#        . elonmusk
#        . europe
#        . nftsplanett
#        . plan
#        . stackswap
#        . closed
#        . eth
#        . worth
#        . mined
#        . attack
#        . help
#        . great
#        . capture
#        . roll
#        . want
#        . 000
#        . btc_archive
#        . needs
#        . ready
#        . documentingbtc
#        . stop
#        . support
#        . jack
#        . woke
#        . mariupol
#        . https
#        . position
#        . good
#        . vaccination
#        . open
#        . yesterday
#        . macro
#        . wef
#        . year
#        . nftart
#        . checked
#        . officialpoua
#        . coma
#        . che
#        . id
#        . official
#        . digital
#        . nftartist
#        . ai
#        . berniespofforth
#        . nftcommunity
#        . bitcoin
#        . announced
#        . charismanfts
#        . like
#        . nfts
#        . understood
#        . scarce
#        . war
#        . defi
#        . promote
#   . Most correlated bigrams:
#        . cryptocurrency bitcoin
#        . president volodymyr
#        . telegram channel
#        . new cases
#        . russia ukraine
#        . rt garethsoloway
#        . btc_archive breaking
#        . russia amp
#        . decentralized finance
#        . bitcoin ethereum
#        . days bitcoin
#        . xrpsec https
#        . ukraine https
#        . rt innasovsun
#        . rt drericding
#        . ukrainian air
#        . cryptojebb bitcoin
#        . covid19 pandemic
#        . bitcoin exchange
#        . russia state
#        . bitcoin fixes
#        . ukraine russia
#        . years ago
#        . russia putin
#        . russia invasion
#        . bitcoin amp
#        . tucker carlson
#        . rt oryxspioenkop
#        . rt tpyxanews
#        . rt bitcoinmagazine
#        . 12 03
#        . 03 2022
#        . rt cryptojebb
#        . stackswap_btc stackswap
#        . passes token
#        . silver passes
#        . prizes nfts
#        . tokens 000
#        . 000 winners
#        . stsw tokens
#        . token 10
#        . 000 silver
#        . rt stackswap_btc
#        . stackswap giveaway
#        . 000 stsw
#        . gold passes
#        . 10 gold
#        . passes 000
#        . giveaway prizes
#        . covid 19
#        . amp crypto
#        . rt martiniguyyt
#        . rt picardonhealth
#        . bot https
#        . finance tata
#        . finance completely
#        . coin aims
#        . secure provide
#        . rt tata_coin
#        . coin new
#        . completely secure
#        . aims make
#        . tata_coin tata
#        . era finance
#        . make decentralized
#        . times ll
#        . start referring
#        . referring covid19
#        . laurie_garrett ve
#        . said times
#        . say pundits
#        . ve said
#        . pundits start
#        . rt laurie_garrett
#        . mexico declare
#        . mexicannewsiine breaking
#        . breaking mexico
#        . rt mexicannewsiine
#        . tender updates
#        . rt goingparabolic
#        . rt numbers28
#        . congress rand
#        . numbers28 heartless
#        . heartless soulless
#        . soulless russian
#        . paul rails
#        . russian butcher
#        . rand ayn
#        . propagandists congress
#        . rails tsa
#        . butcher propagandists
#        . ayn paul
#        . news bitcoin
#        . denying existence
#        . govt gross
#        . gross oversights
#        . oversights amp
#        . existence tcells
#        . negligence denying
#        . amp negligence
#        . highlighted trudeau
#        . tcells publicly
#        . trudeau govt
#        . russian forces
#        . crypto bitcoin
#        . nfts 10
#        . carlson russia
#        . day tucker
#        . rt juliadavisnews
#        . tv clip
#        . juliadavisnews day
#        . russians promote
#        . clip used
#        . used russians
#        . russia https
#        . bitcoin cryptocurrency
#        . cannonfodder corrupt
#        . new era
#        . story develops
#        . updates come
#        . come story
#        . airdrop bot
#        . deputy foreign
#        . russia russianukrainianwar
#        . freedom start
#        . coryklippsten breaking
#        . rt coryklippsten
#        . regulation voted
#        . rt watcherguru
#        . nato russia
#        . state tv
#        . rt thecryptolark
#        . rt airdropdet
#        . start airdrop
#        . airdropdet new
#        . reserves dropped
#        . just bitcoin
#        . covid19 update
#        . work mining
#        . way eu
#        . crypto regulation
#        . bitcoin proof
#        . eu crypto
#        . cryptowhale breaking
#        . ban way
#        . breaking france
#        . going 100
#        . bitcoin going
#        . ll say
#        . military equipment
#        . tata coin
#        . france declare
#        . tender french
#        . french news
#        . lowest level
#        . dropped lowest
#        . level years
#        . rt indiatoday
#        . mining ban
#        . exchange reserves
#        . easily sheep
#        . usa ppl
#        . clue easily
#        . sheep ukraine
#        . ppl clue
#        . ppl cannonfodder
#        . blamegamebiden usa
#        . ukraine ppl
#        . banks freeze
#        . freeze money
#        . money disagree
#        . watcherguru just
#        . steve wozniak
#        . ukrainian forces
#        . cutting supplies
#        . ajit pai
#        . censorship limited
#        . youranonnews mistake
#        . internet censorship
#        . china post
#        . nationalized internet
#        . trump ajit
#        . limited russia
#        . mistake believing
#        . post trump
#        . pai ho
#        . rt youranonnews
#        . believing nationalized
#        . cryptocurrency trading
#        . russian army
#        . rt dockaurg
#        . zoom bitcoin
#        . danheld doubt
#        . doubt zoom
#        . disagree bitcoin
#        . 28 comes
#        . 28 boosted
#        . jonathanweisman 28
#        . rt jonathanweisman
#        . comes ba
#        . boosted 28
#        . breaking bitcoin
#        . foreign minister
#        . fukuyamafrancis thinks
#        . needs start
#        . start preparing
#        . thinks world
#        . preparing defeat
#        . world needs
#        . given situation
#        . fsistanford given
#        . defeat rus
#        . situation ground
#        . rt fsistanford
#        . ground fukuyamafrancis
#        . 10 000
#        . airdrop foodchain
#        . winners 1000
#        . food total
#        . worth food
#        . 1000 random
#        . food rate
#        . global food
#        . foodchain global
#        . meet shameless
#        . denier chap
#        . wrote book
#        . chap wrote
#        . cleansing denier
#        . book glorifying
#        . ethnic cleansing
#        . rt kanchangupta
#        . disastrous management
#        . kanchangupta meet
#        . kashmir ethnic
#        . kerala disastrous
#        . glorifying kerala
#        . shameless kashmir
#        . web https
#        . pool start
#        . referral pool
#        . terra luna
#        . btc terra
#        . bitcoin mining
#        . declare bitcoin
#        . reportedly ukrainian
#        . russian troops
#        . rt dennis_porter_
#        . bitcoinmagazine banks
#        . bitcoin sarang
#        . rt manish_jha_brj
#        . powerful country
#        . america china
#        . like america
#        . russia powerful
#        . bitcoin btc
#        . marketplace https
#        . amp 100
#        . bitcoin great
#        . martiniguyyt week
#        . gift 150
#        . wish gift
#        . 150 bitcoins
#        . equipment ukraine
#        . bitcoinmagazine bitcoin
#        . cream https
#        . rt nexta_tv
#        . sarang india
#        . marketplace web
#        . bad news
#        . secretary health
#        . country like
#        . rt danheld
#        . ticket financial
#        . rt independent
#        . reward 000
#        . rt blue_sauron
#        . moooon altcoin
#        . ready moooon
#        . binance xrp
#        . ripple xrpsec
#        . xrp getting
#        . bitcoin binance
#        . altcoin bitcoin
#        . xrp ripple
#        . financial freedom
#        . 20 000
#        . rt cryptowhale
#        . rt jolitaihuttu
#        . week bitcoin
#        . bitcoin dubai
#        . 81 people
#        . ka 52
#        . creamfinance cream
#        . assistant secretary
#        . oblast russia
#        . software ticket
#        . russia china
#        . signals bitcoin
#        . el salvador
#        . trading software
#        . new airdrop
#        . 000 worth
#        . random amp
#        . luna creamfinance
#        . think bitcoin
#        . rt airdropinspect
#        . rate winners
#        . airdropinspect new
#        . total reward
#        . freedom automated
#        . automated cryptocurrency
#        . people died
#        . eu pow
#        . live soon
#        . presale live
#        . soon 1000x
#        . inside russia
#        . covid19 cases
#        . captured russian
#        . bitcoin legal
#        . apple founder
#        . russia lost
#        . covid19 deaths
#        . bitcoin freedom
#        . proof work
#        . pow ban
#        . 600 russian
#        . legal tender
#        . innasovsun russia
#        . btc_archive bitcoin
#        . getting ready
#        . nft marketplace
#        . bitcoin currently
#        . vaccine doses
#        . looks like
#        . opensea https
#        . btcanalysis onchainlabs
#        . amp information
#        . token kyc
#        . rewards nft
#        . audit busd
#        . 1000x token
#        . busd rewards
#        . kyc audit
#        . shorts binance
#        . 50 shorts
#        . ready fly
#        . futures rocket
#        . binance futures
#        . follow tradeosiann
#        . fly follow
#        . rocket ready
#        . tradeosiann https
#        . russia war
#        . russians liquidating
#        . dubai real
#        . billions bitcoin
#        . just russians
#        . liquidating billions
#        . source reuters
#        . estate source
#        . xrpcommunity ripple
#        . altcoin xrpsec
#        . today 140
#        . yesterday 70
#        . yeahh xrpcommunity
#        . cryptocurrency altcoin
#        . 70 000
#        . 000 xrp
#        . 140 000
#        . 000 yeahh
#        . xrp today
#        . ripple cryptocurrency
#        . covid19 https
#        . ukraine considered
#        . carrying military
#        . minister says
#        . russia deputy
#        . inteldoge russia
#        . rt inteldoge
#        . rt airdropstario
#        . bitcoin https
#        . march 2022
#        . bitcoin cancelled
#        . bitcoin moving
#        . currently https
#        . got rejected
#        . horizontal resistance
#        . 42500 currently
#        . moving ascending
#        . rejected horizontal
#        . triangle got
#        . resistance 42500
#        . ascending triangle
#        . zelensky says
#        . says 600
#        . troops surrendered
#        . sanctions russia
#        . war ukraine
#        . propagandists solovyov
#        . talk sanctions
#        . solovyov says
#        . russia kremlin
#        . says talk
#        . kremlin propagandists
#        . ukraine war
#        . alexkokcharov russia
#        . crypto https
#        . live ukraine
#        . follow live
#        . face airdrop
#        . face referral
#        . amp inf
#        . airdropstario facedao
#        . task million
#        . referral million
#        . facedao airdrop
#        . kplay airdrop
#        . kplay referral
#        . koraplay airdrop
#        . 5000 kplay
#        . airdropstario koraplay
#        . task 5000
#        . referral 500
#        . 500 kplay
#        . sanctions like
#        . airdrop task
#        . rt alexkokcharov
#        . army voting
#        . rt johnsweeneyroar
#        . johnsweeneyroar russian
#        . voting feet
#        . don know
#        . promote nft_sale_
#        . nftcommunity nftcollector
#        . nftart nftcommunity
#        . nft nftart
#        . rovercrc bitcoin
#        . 50 000
#        . russia doing
#        . nfts nftcommunity
#        . russian tank
#        . real estate
#        . nfts nft
#        . bitcoin crypto
#        . nftcommunity nftartist
#        . nftartist nftdrops
#        . check item
#        . opensea nft
#        . item opensea
#        . nftdrops https
# ...
#        . coryklippsten
#        . roll
#        . capture
#        . ka
#        . apartment
#        . lost
#        . feel
#        . oblast
#        . zelenskyyua
#        . assistant
#        . european
#        . independent
#        . left
#        . realise
#        . years
#        . plan
#        . ban
#        . aircraft
#        . month
#        . brigade
#        . troops
#        . case
#        . coincidence
#        . dna
#        . real
#        . 52
#        . 82
#        . innasovsun
#        . london
#        . tank
#        . likely
#        . kyiv
#        . cardano
#        . just
#        . exchange
#        . kremlin
#        . control
#        . rovercrc
#        . region
#        . abandoned
#        . airspace
#        . elonmusk
#        . provide
#        . detained
#        . tata
#        . banned
#        . position
#        . energy
#        . bot
#        . eu
#        . dollar
#        . holding
#        . 81
#        . civilians
#        . warns
#        . 33
#        . cryptojebb
#        . potus
#        . defeat
#        . 20
#        . getting
#        . children
#        . sheep
#        . clue
#        . easily
#        . blamegamebiden
#        . cannonfodder
#        . wef
#        . vote
#        . https
#        . yes
#        . recently
#        . city
#        . nftart
#        . airdropdet
#        . pool
#        . denmark
#        . mass
#        . levels
#        . high
#        . guys
#        . oryxspioenkop
#        . nftcommunity
#        . rus
#        . surge
#        . testing
#        . russianukrainianwar
#        . moving
#        . officialpoua
#        . building
#        . coma
#        . che
#        . report
#        . nfts
#        . id
#        . march
#        . interview
#        . tokens
#        . soldiers
#        . nft
#        . end
#        . nftartist
#        . tests
#        . anti
#        . possible
#        . ve
#        . coin
#        . ai
#        . game
#        . reports
#        . berniespofforth
#        . small
#        . jonathanweisman
#        . investors
#        . foodchain
#        . rt
#        . better
#        . melitopol
#        . school
#        . innovation
#        . deputy
#        . got
#        . zelenskyy
#        . bad
#        . declare
#        . checked
#        . early
#        . rest
#        . cutting
#        . needs
#        . internet
#        . trading
#        . official
#        . positive
#        . macro
#        . face
#        . soon
#        . team
#        . manish_jha_brj
#        . dead
#        . 27
#        . boosted
#        . open
#        . near
#        . thecryptolark
#        . gift
#        . wish
#        . bitcoins
#        . protect
#        . announced
#        . 42500
#        . ascending
#        . triangle
#        . horizontal
#        . mayor
#        . web
#        . 150
#        . parliament
#        . airdrop
#        . rejected
#        . blue_sauron
#        . understood
#        . killed
#        . amazing
#        . moooon
#        . goes
#        . scarce
#        . cancelled
#        . thank
#        . jolitaihuttu
#        . resistance
#        . ukraine
#        . nexta_tv
#        . away
#        . solution
#        . financial
#        . growing
#        . chance
#        . 50
#        . powerful
#        . ppl
#        . shorts
#        . defi
#        . treasury
#        . yesterday
#        . value
#        . classic
#        . software
#        . russia
#        . giveaway
#        . ticket
#        . propaganda
#        . random
#        . nice
#        . share
#        . interesting
#        . airdropinspect
#        . russian
#        . looks
#        . xrp
#        . talk
#        . automated
#        . legal
#        . love
#        . payments
#        . marketplace
#        . mariupol
#        . attack
#        . fly
#        . want
#        . rocket
#        . binance
#        . tender
#        . perfect
#        . futures
#        . giving
#        . token
#        . trust
#        . 1000x
#        . presale
#        . military
#        . deaths
#        . propagandists
#        . alexkokcharov
#        . excellent
#        . kyc
#        . audit
#        . tradeosiann
#        . community
#        . economic
#        . true
#        . free
#        . busd
#        . join
#        . save
#        . friends
#        . thanks
#        . peace
#        . rate
#        . strong
#        . rewards
#        . winners
#        . solovyov
#        . great
#        . huge
#        . support
#        . war
#        . reward
#        . nft_sale_
#        . freedom
#        . worth
#        . help
#        . project
#        . ready
#        . best
#        . nftsplanett
#        . good
#        . like
#        . charismanfts
#        . promote
#   . Most correlated bigrams:
#        . covid 19
#        . rt btc_archive
#        . steve wozniak
#        . rt drericding
#        . proof work
#        . btc_archive bitcoin
#        . terra luna
#        . btc terra
#        . rt goingparabolic
#        . pow ban
#        . tucker carlson
#        . state tv
#        . amp crypto
#        . bitcoin amp
#        . ukraine https
#        . russian forces
#        . bitcoinmagazine banks
#        . decentralized finance
#        . going 100
#        . bitcoin going
#        . ukrainian forces
#        . president volodymyr
#        . bitcoin crypto
#        . bitcoin btc
#        . apple founder
#        . bitcoin cryptocurrency
#        . opensea https
#        . think bitcoin
#        . vaccine doses
#        . rt dockaurg
#        . eu pow
#        . cream https
#        . rt picardonhealth
#        . cryptocurrency bitcoin
#        . rt airdropstario
#        . bitcoin dubai
#        . new cases
#        . russia putin
#        . signals bitcoin
#        . creamfinance cream
#        . covid19 pandemic
#        . march 2022
#        . rt watcherguru
#        . el salvador
#        . 12 03
#        . 03 2022
#        . bitcoin sarang
#        . luna creamfinance
#        . btc_archive breaking
#        . rt martiniguyyt
#        . russian army
#        . airdrop task
#        . russia china
#        . sarang india
#        . inside russia
#        . breaking bitcoin
#        . btcanalysis onchainlabs
#        . watcherguru just
#        . rt cryptowhale
#        . bitcoin mining
#        . amp information
#        . crypto bitcoin
#        . disagree bitcoin
#        . russian troops
#        . captured russian
#        . say pundits
#        . start referring
#        . ve said
#        . pundits start
#        . referring covid19
#        . rt laurie_garrett
#        . times ll
#        . laurie_garrett ve
#        . said times
#        . rt dennis_porter_
#        . innasovsun russia
#        . soulless russian
#        . butcher propagandists
#        . numbers28 heartless
#        . rt numbers28
#        . congress rand
#        . rand ayn
#        . rails tsa
#        . paul rails
#        . russian butcher
#        . propagandists congress
#        . ayn paul
#        . heartless soulless
#        . nato russia
#        . negligence denying
#        . trudeau govt
#        . existence tcells
#        . highlighted trudeau
#        . amp negligence
#        . oversights amp
#        . govt gross
#        . denying existence
#        . gross oversights
#        . tcells publicly
#        . 50 000
#        . rt garethsoloway
#        . bitcoin fixes
#        . russia amp
#        . russia invasion
#        . crypto https
#        . sanctions russia
#        . dubai real
#        . source reuters
#        . estate source
#        . liquidating billions
#        . just russians
#        . billions bitcoin
#        . russians liquidating
#        . 000 yeahh
#        . today 140
#        . ripple cryptocurrency
#        . 70 000
#        . yeahh xrpcommunity
#        . altcoin xrpsec
#        . cryptocurrency altcoin
#        . yesterday 70
#        . xrp today
#        . xrpcommunity ripple
#        . 140 000
#        . 000 xrp
#        . regulation voted
#        . deputy foreign
#        . reserves dropped
#        . just bitcoin
#        . work mining
#        . eu crypto
#        . way eu
#        . bitcoin proof
#        . cryptowhale breaking
#        . crypto regulation
#        . ban way
#        . carrying military
#        . rt inteldoge
#        . inteldoge russia
#        . minister says
#        . russia deputy
#        . ukraine considered
#        . ll say
#        . russia doing
#        . zelensky says
#        . troops surrendered
#        . says 600
#        . cryptojebb bitcoin
#        . foreign minister
#        . lowest level
#        . level years
#        . dropped lowest
#        . russia state
#        . telegram channel
#        . nfts nftcommunity
#        . giveaway prizes
#        . silver passes
#        . passes 000
#        . stackswap giveaway
#        . stsw tokens
#        . tokens 000
#        . token 10
#        . 000 silver
#        . 000 stsw
#        . 000 winners
#        . stackswap_btc stackswap
#        . 10 gold
#        . gold passes
#        . passes token
#        . prizes nfts
#        . rt stackswap_btc
#        . mining ban
#        . exchange reserves
#        . live ukraine
#        . follow live
#        . russian tank
#        . airdropstario facedao
#        . face airdrop
#        . amp inf
#        . referral million
#        . task million
#        . facedao airdrop
#        . face referral
#        . 500 kplay
#        . referral 500
#        . task 5000
#        . koraplay airdrop
#        . kplay airdrop
#        . kplay referral
#        . 5000 kplay
#        . airdropstario koraplay
#        . banks freeze
#        . money disagree
#        . freeze money
#        . news bitcoin
#        . rt indiatoday
#        . bitcoin exchange
#        . russia ukraine
#        . 600 russian
#        . 100 000
#        . don know
#        . censorship limited
#        . mistake believing
#        . limited russia
#        . pai ho
#        . post trump
#        . ajit pai
#        . nationalized internet
#        . believing nationalized
#        . youranonnews mistake
#        . rt youranonnews
#        . internet censorship
#        . china post
#        . trump ajit
#        . voting feet
#        . rt johnsweeneyroar
#        . johnsweeneyroar russian
#        . army voting
#        . rt documentingbtc
#        . zoom bitcoin
#        . doubt zoom
#        . danheld doubt
#        . ukrainian air
#        . equipment ukraine
#        . nftart nftcommunity
#        . nft nftart
#        . nftcommunity nftcollector
#        . russia https
#        . covid19 https
#        . fsistanford given
#        . defeat rus
#        . needs start
#        . situation ground
#        . start preparing
#        . given situation
#        . fukuyamafrancis thinks
#        . ground fukuyamafrancis
#        . rt fsistanford
#        . world needs
#        . preparing defeat
#        . thinks world
#        . bitcoin ethereum
#        . denier chap
#        . cleansing denier
#        . rt kanchangupta
#        . chap wrote
#        . meet shameless
#        . glorifying kerala
#        . wrote book
#        . kanchangupta meet
#        . kerala disastrous
#        . kashmir ethnic
#        . ethnic cleansing
#        . shameless kashmir
#        . book glorifying
#        . disastrous management
#        . days bitcoin
#        . era finance
#        . finance completely
#        . finance tata
#        . completely secure
#        . tata_coin tata
#        . coin aims
#        . coin new
#        . make decentralized
#        . secure provide
#        . aims make
#        . rt tata_coin
#        . real estate
#        . nfts nft
#        . military equipment
#        . tender updates
#        . mexico declare
#        . rt mexicannewsiine
#        . breaking mexico
#        . mexicannewsiine breaking
#        . rt independent
#        . years ago
#        . nftartist nftdrops
#        . check item
#        . nftdrops https
#        . item opensea
#        . opensea nft
#        . nftcommunity nftartist
#        . xrpsec https
#        . nfts 10
#        . rt saylor
#        . 000th bitcoin
#        . days 19
#        . 000 000th
#        . 22 days
#        . 19 000
#        . juliadavisnews day
#        . day tucker
#        . rt juliadavisnews
#        . carlson russia
#        . clip used
#        . russians promote
#        . tv clip
#        . used russians
#        . ukraine war
#        . cannonfodder corrupt
#        . new era
#        . bad news
#        . nft nfts
#        . come story
#        . updates come
#        . story develops
#        . secretary health
#        . russia russianukrainianwar
#        . rt danheld
#        . rt tpyxanews
#        . bitcoin mined
#        . nexta_tv new
#        . million face
#        . bitcoin https
#        . freedom start
#        . reportedly ukrainian
#        . 10 000
#        . coryklippsten breaking
#        . rt coryklippsten
#        . 81 people
#        . link amp
#        . airdrop link
#        . wef capture
#        . coincidence announced
#        . yesterday plan
#        . roll digital
#        . announced yesterday
#        . id wef
#        . capture dna
#        . berniespofforth coincidence
#        . plan roll
#        . ka 52
#        . bot https
#        . assistant secretary
#        . russia announced
#        . new sanctions
#        . breaking france
#        . rt innasovsun
#        . russia war
#        . tata coin
#        . tender french
#        . france declare
#        . french news
#        . announced today
#        . airdrop bot
#        . rt bitcoinmagazine
#        . rovercrc bitcoin
#        . people died
#        . ukraine russia
#        . week bitcoin
#        . country like
#        . covid19 cases
#        . clue easily
#        . ppl cannonfodder
#        . ppl clue
#        . sheep ukraine
#        . usa ppl
#        . blamegamebiden usa
#        . easily sheep
#        . ukraine ppl
#        . start airdrop
#        . rt airdropdet
#        . airdropdet new
#        . russia lost
#        . covid19 deaths
#        . rt oryxspioenkop
#        . cutting supplies
#        . year coma
#        . just woke
#        . don position
#        . eth just
#        . position bitcoin
#        . woke year
#        . checked macro
#        . coma checked
#        . che https
#        . macro che
#        . digital id
#        . rt berniespofforth
#        . comes ba
#        . jonathanweisman 28
#        . boosted 28
#        . rt jonathanweisman
#        . 28 boosted
#        . 28 comes
#        . covid19 update
#        . rt rovercrc
#        . food total
#        . food rate
#        . worth food
#        . global food
#        . foodchain global
#        . 1000 random
#        . airdrop foodchain
#        . winners 1000
#        . rt cryptojebb
#        . web https
#        . referral pool
#        . pool start
#        . war ukraine
#        . bitcoin eth
#        . declare bitcoin
#        . saylor bitcoin
#        . oblast russia
#        . rt thecryptolark
#        . rt manish_jha_brj
#        . like america
#        . powerful country
#        . america china
#        . russia powerful
#        . bitcoinmagazine bitcoin
#        . marketplace https
#        . amp 100
#        . martiniguyyt week
#        . bitcoin great
#        . wish gift
#        . gift 150
#        . 150 bitcoins
#        . scarce understood
#        . bitcoin scarce
#        . bitcoin cancelled
#        . bitcoin moving
#        . currently https
#        . rejected horizontal
#        . 42500 currently
#        . resistance 42500
#        . triangle got
#        . horizontal resistance
#        . ascending triangle
#        . got rejected
#        . moving ascending
#        . cryptocurrency trading
#        . looks like
#        . marketplace web
#        . rt blue_sauron
#        . ticket financial
#        . reward 000
#        . bitcoin binance
#        . ready moooon
#        . ripple xrpsec
#        . binance xrp
#        . moooon altcoin
#        . altcoin bitcoin
#        . xrp getting
#        . xrp ripple
#        . financial freedom
#        . 20 000
#        . rt jolitaihuttu
#        . software ticket
#        . rt nexta_tv
#        . trading software
#        . 000 worth
#        . random amp
#        . rt airdropinspect
#        . airdropinspect new
#        . rate winners
#        . total reward
#        . automated cryptocurrency
#        . freedom automated
#        . bitcoin legal
#        . bitcoin freedom
#        . legal tender
#        . getting ready
#        . new airdrop
#        . presale live
#        . live soon
#        . soon 1000x
#        . nft marketplace
#        . bitcoin currently
#        . rt alexkokcharov
#        . kyc audit
#        . audit busd
#        . rewards nft
#        . 1000x token
#        . busd rewards
#        . token kyc
#        . 50 shorts
#        . ready fly
#        . shorts binance
#        . rocket ready
#        . futures rocket
#        . tradeosiann https
#        . fly follow
#        . binance futures
#        . follow tradeosiann
#        . alexkokcharov russia
#        . sanctions like
#        . propagandists solovyov
#        . russia kremlin
#        . talk sanctions
#        . says talk
#        . kremlin propagandists
#        . solovyov says
#        . promote nft_sale_
#        . promote nftsplanett
#        . promote charismanfts

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import accuracy_score



X = df['text']
y = df['Polarity_int']

    # mlflow.log_param("training percencentage",70)
    # mlflow.log_param("database shape",df.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y)
vectorizer = TfidfVectorizer(stop_words='english')
X_train_dtm = vectorizer.fit_transform(X_train)
X_test_dtm = vectorizer.transform(X_test)

clf_lr = LogisticRegression()
clf_lr.fit(X_train_dtm, y_train)
y_pred = clf_lr.predict(X_test_dtm)
lr_score = accuracy_score(y_test, y_pred) # perfectly balanced binary classes

clf_mnb = MultinomialNB()
clf_mnb.fit(X_train_dtm, y_train)
y_pred = clf_mnb.predict(X_test_dtm)
mnb_score = accuracy_score(y_test, y_pred) # perfectly balanced binary classes

# %%
y.shape
# Out:
# (3946,)

# %%
print(X_test_dtm)
# Out:
#   (0, 7299)	0.23677396806079018
#   (0, 6475)	0.06377490140019665
#   (0, 6231)	0.22038067947097054
#   (0, 4932)	0.44974743987619564
#   (0, 4547)	0.2380361974571192
#   (0, 3910)	0.2708583351655942
#   (0, 2958)	0.2708583351655942
#   (0, 2954)	0.5028505395106776
#   (0, 827)	0.15653069589869087
#   (0, 743)	0.2380361974571192
#   (0, 736)	0.38938282517223594
#   (1, 6475)	0.17799651793789464
#   (1, 3378)	0.6386811931166922
#   (1, 1821)	0.7486010774511502
#   (2, 6978)	0.4845969567610618
#   (2, 6475)	0.08551376195761282
#   (2, 6281)	0.40365594110875835
#   (2, 3920)	0.32846250670460675
#   (2, 3735)	0.1144564382761799
#   (2, 3437)	0.3445920023649643
#   (2, 2491)	0.35630848218187666
#   (2, 1225)	0.1256087919563414
#   (2, 654)	0.460923227297621
#   (3, 6475)	0.09892760395236563
#   (3, 5109)	0.5137929198668812
#   :	:
#   (982, 3735)	0.3131306982614785
#   (983, 5940)	0.5916667147262804
#   (983, 5237)	0.8061826707918065
#   (984, 7396)	0.5533406928217307
#   (984, 6475)	0.09764453455028411
#   (984, 5208)	0.3243995783698054
#   (984, 4266)	0.526308666144284
#   (984, 2099)	0.36064197496720973
#   (984, 1190)	0.4147060283221034
#   (985, 3360)	0.77028404586142
#   (985, 1416)	0.5781755116604522
#   (985, 1225)	0.269027073744514
#   (986, 8239)	0.23650106959791686
#   (986, 7436)	0.29986051364338606
#   (986, 7047)	0.25260951222652345
#   (986, 6854)	0.2901017398372159
#   (986, 6497)	0.29191131833063844
#   (986, 6475)	0.07552670584176926
#   (986, 5868)	0.297755417461773
#   (986, 5182)	0.27224507231607437
#   (986, 3476)	0.2883535149446809
#   (986, 3361)	0.3020552148787575
#   (986, 3251)	0.3067464198329987
#   (986, 3240)	0.3067464198329987
#   (986, 2254)	0.29986051364338606

# %%
prediction=clf_mnb.predict(vectorizer.transform(["OurWorldInData"]))
print(type(prediction))
# Out:
# <class 'numpy.ndarray'>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
import warnings
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import mlflow
import mlflow.sklearn
from urllib.parse import urlparse




def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2

def fetch_logged_data(run_id):

    client = mlflow.tracking.MlflowClient()
    data = client.get_run(run_id).data
    tags = {k: v for k, v in data.tags.items() if not k.startswith("mlflow.")}
    artifacts = [f.path for f in client.list_artifacts(run_id, "model")]
    return data.params, data.metrics, tags, artifacts



mlflow.log_artifacts

mlflow.set_tracking_uri("http://127.0.0.1:5000")

#this is model registry
registry_uri='sqlite:///mlflow.db'

#update the date in the real time from the above sql lite db

mlflow.tracking.set_tracking_uri(registry_uri)

mlflow.end_run()





if __name__ == "__main__":
    warnings.filterwarnings("ignore")
    np.random.seed(40)

with mlflow.start_run():
    model=LogisticRegression(random_state=0)
    model.fit(X_train_dtm.toarray(), y_train)

    predicted_qualities = model.predict(X_test_dtm.toarray())

    (rmse, mae, r2) = eval_metrics(y_test, predicted_qualities)


    print("  RMSE: %s" % rmse)
    print("  MAE: %s" % mae)
    print("  R2: %s" % r2)

        
        
        
    #mlflow.log_metric("Accuracy", accuracy)
    mlflow.log_metric("rmse", rmse)
    mlflow.log_metric("r2", r2)
    mlflow.log_metric("mae", mae)

    tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme

    if tracking_url_type_store != "file":

    # Register the model
    # There are other ways to use the Model Registry, which depends on the use case,
    # please refer to the doc for more information:
    # https://mlflow.org/docs/latest/model-registry.html#api-workflow
        mlflow.sklearn.log_model(model,'Logistic regression models',registered_model_name='Logistic regression model')
    else:
        mlflow.sklearn.log_model(model, "model")

mlflow.end_run()
# Out:
#   RMSE: 0.5954913341754137
#   MAE: 0.2553191489361702
#   R2: 0.4436015384912735
# Registered model 'Logistic regression model' already exists. Creating a new version of this model...
# 2022/03/14 11:19:59 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Logistic regression model, version 3
# Created version '3' of model 'Logistic regression model'.

# %%
predicted_qualities.shape,y_test.shape
# Out:
# ((987,), (987,))
